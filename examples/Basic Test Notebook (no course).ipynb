# %% [markdown]
# This is an assignment for a student.

# %% [markdown]
# ![addyourtitlehere%20%282%29.png](attachment:addyourtitlehere%20%282%29.png)

# %%
import tate
art = tate.get_artwork()
h = [a['dimensions']['height'] for a in art if a['artist']['birth']['year'] > 1000]
b = [a['artist']['birth']['year'] for a in art 
     if a['artist']['birth']['year'] > 1000]
import matplotlib.pyplot as plt
plt.scatter(b, h, alpha=.1)
plt.show()

# %% [markdown]
# ![ada-pic1.jpg](attachment:ada-pic1.jpg)

# %%
# %grade_blockpy 1
